# %%
import pytesseract
from PIL import Image

# %%
img_file = "data/page_01.jpg"
no_noise = "temp/no_noise.jpg"

# %%
img = Image.open(no_noise)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=591x374>

# %%
ocr_result = pytesseract.image_to_string(img,lang = 'tha+eng')

# %%
print (ocr_result)
# Out:
# ข้อมูลประจําตัวประชาชน Thai National [0 Card Data
#
# เลรบ
# {ee
#
# iva 1 2345 67890 12 3
#
# ริเม๑ะงลก๑ WIE ตัวอย่าง นามรอง สาธิตสกุล
#
# Name Ms. Sample
#
# เก็นวันที่ 30 Ga. 2508
# Date of ith 30 Mat. 1965
#
# Foy บาง หมูที 1 ตรอาปฐม %.#ยุมวิท 1 ฉ. สุขมวิท
#
# แขวงคลองเตะเหนือ เขลพร๊ะโขนง กรุงเทพมหานคร
#
# 315.ด. 2550     4 เมย. 2563   29 มีด 2556
# วันลรกบัตร         114ฐุ02น.     วันบัตรหนดยายู
# 21 Dec 2007      วันเวลาชีสานบัตร    329 Mas ว013
# Date of [แรพด        สกณายรป 0๓๓9๕9๓ Date of Expiry
#
# ใม่ไชค้ตรประจ้าอังประชาชน อรักเภาหปัตรโดย คว้งน(30 1.1 000
#
# Last came MiddleName Satitsakul
#
# เจอสัน
# ne      “one
# 12พ 46789012034
